# %%
from torchvision import datasets, models, transforms
from PIL import Image
import os
import glob
import numpy as np
import torch
import matplotlib.pyplot as plt

# %%
img = glob.glob("*.JPG")[1]
image = Image.open(img)

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=375x500 at 0x12771F63280>

# %%
a = transforms.RandomApply([transforms.GaussianBlur(5, sigma=(0.5, 5))], p = 0.1)

# %%
for _ in range(10):
    plt.imshow(np.array(a(image)))
    plt.show()
